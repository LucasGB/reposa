# %%
# Ignore sklearn future warning.
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

from SentiCR.SentiCR import SentiCR
from SentiSW.code.classification.classifier import Classifier
from SentiSW.code.entity.training_set_generation import get_entity
import scikitplot as skplt
import matplotlib.pyplot as plt
import pandas as pd
import pickle

# Config NLTK java file finder.
import os
java_path = "C:/Program Files (x86)/Java/jre1.8.0_241/bin/java.exe"
os.environ['JAVAHOME'] = java_path


dir_path = os.path.abspath(os.getcwd())

# Classifier's model path
SentiCRModelPath = dir_path + "/SentiCR/SentiCR/models/SentiCR_model.pkl"
SentiCR_trainning_file_path = dir_path + '/SentiCR/SentiCR/oracle.xlsx'


# AQUI
SentiSWModelPath = dir_path + "/SentiSW/data/model/sentimentClassification/classifier_sentiSW+_(preds)_no_chinese_chars.pkl"

SentiSW_trainning_no_chinese_file_path = dir_path + '/SentiSW/data/training_set_3000_no_chinese.csv'
SentiSW_trainning_file_path = dir_path + '/SentiSW/data/training_set_3000.csv'


# Gold Standard
gold_file_path = dir_path + '/Senti4SD_GoldStandard_EmotionPolarity.xlsx'

def SentiSW_classify_labels(text):
    if(os.path.exists(SentiSWModelPath)):
        sentiment_analyzer = Classifier(read=True, vector_method='tfidf')
        #sentiment_analyzer.save_model()
    else:
        sentiment_analyzer = Classifier(read=False, vector_method='tfidf')
    sentiment = sentiment_analyzer.get_sentiment_polarity_label(text)[0]
    ret = {'sentiment': sentiment}
    if sentiment != 'Neutral':
        entity = get_entity(text)
        ret['entity'] = entity
    else:
        ret['entity'] = None

    return ret

def SentiSW_classify_probas(text):
    if(os.path.exists(SentiSWModelPath)):
        sentiment_analyzer = Classifier(read=True, vector_method='tfidf')
        #sentiment_analyzer.save_model()
    else:
        sentiment_analyzer = Classifier(read=False, vector_method='tfidf')
    sentiment = sentiment_analyzer.get_sentiment_polarity_proba(text)[0]
    ret = {'sentiment': sentiment}
    if sentiment != 'Neutral':
        entity = get_entity(text)
        ret['entity'] = entity
    else:
        ret['entity'] = None

    return ret

# %%
def convert_to_binary_prediction(preds):
    negative = preds[0]
    non_negative = preds[1] + preds[2]
    
    #diff = abs(positive + negative - 1)
    
    #positive += (diff/2)
    #negative += (diff/2)
    
    return [negative, non_negative]

# %%
def sentiSW_predict_labels(test, name):
    count = 0
    sentiSW_predictions = []
    for text in test:
        print(count)
        count += 1
        sentiSW_predictions.append(SentiSW_classify_labels(text))
        
    with open(name, 'wb') as f:
        pickle.dump(sentiSW_predictions, f)

    return sentiSW_predictions

def sentiSW_predict_probas(test, name):
    count = 0
    sentiSW_predictions = []
    for text in test:
        print(count)
        count += 1
        sentiSW_predictions.append(SentiSW_classify_probas(text))
        
    with open(name, 'wb') as f:
        pickle.dump(sentiSW_predictions, f)

    return sentiSW_predictions

# %%
def ROC_curve(y_true, y_pred, roc_name):
    skplt.metrics.plot_roc(y_true, y_pred, title="ROC Curve for SentiSW+ (preds) (No Chinese Characters) predictions on GoldTest")

    fig = plt.gcf()

    fig.set_size_inches(8, 8)
    plt.savefig(roc_name, dpi=100)

    plt.show()

# %% [markdown]
# # SentiCR dataset

# %%
sentiCR_df = pd.read_excel(SentiCR_trainning_file_path, names=['text', 'Annotation'])
sentiCR_df
# Out:
#                                                    text  Annotation
# 0     - Should be like below:\ntextDirection = SWT.A...           0
# 1     """create a vdsm.config.config clone, modified...           0
# 2     "Add test(s) performing the static code analys...           0
# 3     "apt-get" is distro specific... perhaps make i...           0
# 4     "easy" is marketing; let the code speak for it...           0
# ...                                                 ...         ...
# 1594  you'll need someone with some maven experience...           0
# 1595  Your memory is too smalll. Consider buying a R...           0
# 1596  You're preforming this check multiple times.\n...           0
# 1597  You're right. Ivan,tenant_id is non-admin tena...           0
# 1598  You're right. The issue is that the onSampleSe...           0
#
# [1599 rows x 2 columns]

# %% [markdown]
# # SentiSW dataset
#
# <class 'pandas.core.frame.DataFrame'>
#
# RangeIndex: 3000 entries, 0 to 2999
#
# Data columns (total 3 columns):
#
#     Column      Non-Null Count  Dtype
#
#  - 0   issue_id    3000 non-null   int64
#  - 1   Annotation  3000 non-null   object
#  - 2   text        2993 non-null   object
#
#
# First, we load the dataframe from the .csv file and remove rows containing NaN values in the 'text' column. This results in a dataframe containing 2993 rows, down from 3000.

# %%
#sentiSW_df = pd.read_csv(SentiSW_trainning_file_path)
sentiSW_df = pd.read_csv(SentiSW_trainning_no_chinese_file_path)
sentiSW_df.dropna(inplace=True)
sentiSW_df
# Out:
#       issue_id Annotation                                               text
# 0         3001   Negative  I have a component with these options:\r\n\r\n...
# 1         3002    Neutral  ### Version\r\n2.2.5\r\n\r\n### Reproduction l...
# 2         3003   Positive  ### What problem does this feature solve?\r\nL...
# 3         3004    Neutral  I am trying to get some multi page setup simil...
# 4         3005    Neutral  Hi,\r\n\r\nI am using [Vis Network](http://vis...
# ...        ...        ...                                                ...
# 2965      5996    Neutral  Yes.  I definitely think we shoudl have an API...
# 2966      5997    Neutral  I think that this would complicate the languag...
# 2967      5998    Neutral  Another related issue is that we're not proper...
# 2968      5999   Positive  Here are the problems I am hearing about on th...
# 2969      6000    Neutral  From what I've seen so far: it should be easie...
#
# [2970 rows x 3 columns]

# %% [markdown]
# # Gold Standard Dataset

# %%
gold_df = pd.read_excel(gold_file_path)
gold_df['Final Label (majority voting)'] = gold_df['Final Label (majority voting)'].str.capitalize()
gold_df
# Out:
#                Study  Label  Stack Overflow ID        Post Type  \
# 0              Pilot    pA1                NaN              NaN
# 1              Pilot    pA2                NaN              NaN
# 2              Pilot    pA3                NaN              NaN
# 3              Pilot    pA4                NaN              NaN
# 4              Pilot    pA5                NaN              NaN
# ...              ...    ...                ...              ...
# 4418  Extended Study  tD496           923922.0  QuestionComment
# 4419  Extended Study  tD497         38466121.0    AnswerComment
# 4420  Extended Study  tD498           288982.0           Answer
# 4421  Extended Study  tD499           863762.0  QuestionComment
# 4422  Extended Study  tD500         29109786.0    AnswerComment
#
#                                                    Text  \
# 0     Vineet, what you are trying to do is a terribl...
# 1                              'Course I do, corrected.
# 2     Excellent, happy to help! If you don't mind, c...
# 3     @DrabJay: excellent suggestion! Code changed. :-)
# 4     Any decent browser should protect against mali...
# ...                                                 ...
# 4418  Yes - that feature is extremely useful for wri...
# 4419  Works great! And you can add "desc" after the ...
# 4420  Yeah, I didn't know about the non-greedy thing...
# 4421  Fortunately I'm doing *very* little with Offic...
# 4422  Another very fast approach is the [seek method...
#
#      Final Label (majority voting)        r1        r2        r3
# 0                         Negative  Negative  Negative  Negative
# 1                         Positive  Positive  Positive  Positive
# 2                         Positive   Neutral  Positive  Positive
# 3                         Positive  Positive  Positive  Positive
# 4                          Neutral   Neutral   Neutral   Neutral
# ...                            ...       ...       ...       ...
# 4418                      Positive  Positive  Positive  Positive
# 4419                      Positive  Positive  Positive  Positive
# 4420                      Positive  Positive   Neutral  Positive
# 4421                      Positive  Positive  Positive  Positive
# 4422                       Neutral  Positive   Neutral   Neutral
#
# [4423 rows x 9 columns]

# %% [markdown]
# # SentiSW predictions on GoldTest dataset
#
# classifier = SentiSW
#
# train_set = SentiSW dataset
#
# test_set = GoldTest dataset

# %% [markdown]
# # Predict Labels

# %%
import datetime
import time

start_time = time.time()

# Careful! If this flag is set to true, re-training takes a long time to complete.
load = True

#test = sentiCR_df['text'].tolist()
test = gold_df['Text'].tolist()

name = 'pickled-predictions/sentiSW+_(preds)_label_predictions_on_GoldTest_dataset.pkl'

if(load):
    with open(name, 'rb') as f:
        sentiSW_predictions = pickle.load(f)
else:
    sentiSW_predictions = sentiSW_predict_labels(test, name)

elapsed_time = time.time() - start_time
formatted_elapsed_time = time.strftime("%H:%M:%S", time.gmtime(elapsed_time))

print(formatted_elapsed_time)

sentiSW_predictions

# %%
preds = [sentiSW_predictions[i]['sentiment'] for i in range(len(sentiSW_predictions))]


sentiCR = pd.DataFrame([None for i in range(len(sentiSW_predictions))], columns=['issue_id'])
sentiCR['Annotation'] = pd.Series(preds)
sentiCR['text'] = sentiCR_df['text']
sentiCR

# %%
preds

# %%
df = pd.concat([sentiSW_df, sentiCR], axis=0, ignore_index=True)
df

# %%
df.to_csv ('sentiSW+ (preds) dataset.csv', index = False, header=True)

# %%
converted_predictions = [sentiSW_predictions[i]['sentiment'] for i in range(len(sentiSW_predictions))]
converted_predictions

# %% [markdown]
# # Predict Probabilities

# %%
import datetime
import time

# Careful! If this flag is set to true, re-training takes a long time to complete.
load = True

start_time = time.time()

#test = sentiCR_df['text'].tolist()
test = gold_df['Text'].tolist()

name = 'pickled-predictions/sentiSW+_(preds)_NO_CHINESE_probas_predictions_on_GoldTest_dataset.pkl'

if(load):
    with open(name, 'rb') as f:
        sentiSW_predictions = pickle.load(f)
else:
    sentiSW_predictions = sentiSW_predict_probas(test, name)
    
elapsed_time = time.time() - start_time
formatted_elapsed_time = time.strftime("%H:%M:%S", time.gmtime(elapsed_time))

print(formatted_elapsed_time)

sentiSW_predictions
# Out:
# 00:00:00
# [{'sentiment': array([0.18546569, 0.09265195, 0.72188237]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0
),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.57531814, 0.09520267, 0.32947919]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.31287924, 0.2865271 , 0.40059366]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.21240871, 0.66684419, 0.1207471 ]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.02596092, 0.00861755, 0.96542154]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.20828587, 0.05365165, 0.73806249]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.00913843, 0.01037513, 0.98048644]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.009729  , 0.00782486, 0.98244614]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.01169293, 0.01130282, 0.97700425]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.29612674, 0.64055865, 0.0633146 ]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.07718562, 0.13280808, 0.79000631]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.06430061, 0.21875269, 0.71694671]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.14682064, 0.72120945, 0.13196991]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.2010274 , 0.74523755, 0.05373505]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.09453955, 0.84456353, 0.06089692]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.01997984, 0.02315096, 0.9568692 ]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.11935486, 0.13080011, 0.74984503]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.02114039, 0.00450461, 0.974355  ]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.17320946, 0.12405334, 0.70273721]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.38893064, 0.50009109, 0.11097827]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.50908417, 0.36518665, 0.12572918]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.01535213, 0.0248335 , 0.95981438]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.06437902, 0.09051139, 0.84510959]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.63278653, 0.17220867, 0.1950048 ]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.38050966, 0.40526353, 0.21422681]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.08597408, 0.83674801, 0.07727791]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.07779041, 0.86018621, 0.06202338]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.36960539, 0.59665622, 0.03373839]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.21042715, 0.22871566, 0.56085719]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.13251515, 0.77155195, 0.0959329 ]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.01099008, 0.00892987, 0.98008005]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.01071612, 0.01035861, 0.97892527]),
#   'entity': 'PERSON'},
#  {'sentiment': array([0.12000289, 0.77213237, 0.10786474]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.07779041, 0.86018621, 0.06202338]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.25124717, 0.69839532, 0.05035751]),
#   'entity': 'PROJECT'},
#  {'sentiment': array([0.08597408, 0.83674801, 0.07727791]),
#   'entity': 'PROJECT'},
#  ...]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-29eb1173a97b> in <module>
# ----> 1 len(converted_predictions)
#
# NameError: name 'converted_predictions' is not defined

# %%
roc_name = 'visualizations/sentiSW+_(preds)_NO_CHINESE_probas_predictions_on_GoldTest_dataset.png'

converted_predictions = [convert_to_binary_prediction(sentiSW_predictions[i]['sentiment']) for i in range(len(sentiSW_predictions))]

#y_true = ['Non-Negative' if x != -1 else 'Negative' for x in gold_df['Final Label (majority voting)']]
y_true = ['Negative' if x == 'Negative' else 'Non-Negative' for x in gold_df['Final Label (majority voting)']]


ROC_curve(y_true, converted_predictions, roc_name)

# %% [markdown]
# # Metrics Report

# %%
load = True

test = gold_df['Text'].tolist()
name = 'pickled-predictions/sentiSW+_(preds)_label_predictions_on_GoldTest_dataset.pkl'

if(load):
    with open(name, 'rb') as f:
        sentiSW_predictions = pickle.load(f)
else:
    sentiSW_predictions = sentiSW_predict_labels(test, name)

y_true = ['Non-Negative' if x != -1 else 'Negative' for x in gold_df['Final Label (majority voting)']]

sentiSW_predictions

# %%
y_pred = ['Negative' if i['sentiment'] == 'Negative' else 'Non-Negative' for i in sentiSW_predictions]
y_pred

# %%
from sklearn.metrics import precision_recall_fscore_support

precision_recall_fscore_support(y_true, y_pred, average='macro')

# %%
precision_recall_fscore_support(y_true, y_pred, average='micro')

# %%
precision_recall_fscore_support(y_true, y_pred, average='weighted')

# %% [markdown]
# # Create Excel

# %%
y_pred = [i['sentiment'] for i in sentiSW_predictions]
y_pred = pd.Series(y_pred, name='SentiSW classification')
y_pred

# %%
# TEM QUE DEIXAR AS PREDIÇÕES DE FAIXA 3, ELAS TAO NA 2.

load = True

test = gold_df['Text'].tolist()
name = 'pickled-predictions/sentiSW+_(preds)_label_predictions_on_GoldTest_dataset.pkl'

if(load):
    with open(name, 'rb') as f:
        sentiSW_predictions = pickle.load(f)
else:
    sentiSW_predictions = sentiSW_predict_labels(test, name)
    

# Get Annotation Column
annotation = gold_df.filter(['Final Label (majority voting)'], axis=1)
annotation['GoldTest Manual'] = annotation['Final Label (majority voting)']
annotation.drop(['Final Label (majority voting)'], axis=1, inplace=True)

# Get Text Column
text = gold_df.filter(['Text'], axis=1)

# Get Predictions
'''
preds = []
for i in y_pred:
    if i == 'Negative':
        preds.append(-1)
    elif i == 'Neutral':
        preds.append(0)
    elif i == 'Positive':
        preds.append(1)
'''            
#y_pred = [-1 if x == 'Negative' else 0 for x in y_pred]
#y_pred = pd.DataFrame(y_pred, columns=['SentiSW classification'])

y_pred = [i['sentiment'] for i in sentiSW_predictions]
y_pred = pd.Series(y_pred, name='SentiSW classification')


# Create Dataframe
df = pd.concat([annotation, y_pred, text], axis=1, ignore_index=False)
df

#import openpyxl

#df.to_excel ('(No Chinese Characters) sentiSW+_(preds)_classification_GoldTest_dataset.xlsx', index = False, header=True)

# %%
y_pred

# %% [markdown]
# # Create Contradictions sheet

# %%
y_pred[0]

# %%
if y_pred[0] != 'Negative' and gold_df['Final Label (majority voting)'] != 'Negative':
    print('y')

# %%
load = True

#gold_df = gold_df.reset_index()
test = gold_df['Text'].tolist()
name = 'pickled-predictions/sentiSW+_(preds)_label_predictions_on_GoldTest_dataset.pkl'

if(load):
    with open(name, 'rb') as f:
        sentiSW_predictions = pickle.load(f)
else:
    sentiSW_predictions = sentiSW_predict_labels(test, name)


#y_pred = ['Negative' if i['sentiment'] == 'Negative' else 'Non-Negative' for i in sentiSW_predictions]
#sentiCR = ['Negative' if i == -1 else 'Non-Negative' for i in sentiCR_df['Annotation']]

y_pred = [i['sentiment'] for i in sentiSW_predictions]
y_pred = pd.Series(y_pred, name='SentiSW classification')

aux = []
for i in range(len(gold_df)):
    if(gold_df['Final Label (majority voting)'][i] != 'Negative' and y_pred[i] != 'Negative'):
        continue
    else:
        aux.append([gold_df['Final Label (majority voting)'][i], y_pred[i], gold_df['Text'][i]])

diff = pd.DataFrame(aux, columns=['GoldTest Manual', 'SentiSW classification', 'Text'])

#import openpyxl

#diff.to_excel ('(No Chinese Characters) sentiSW+_(preds)_classification_GoldTest_dataset contradictions.xlsx', index = False, header=True)
#diff

# %% [markdown]
# # Create SentiCR+ train set

# %%
binary_sentiSW_df = sentiSW_df.filter(['text'], axis=1)
binary_sentiSW_df['Annotation'] = pd.Series(sentiSW, index=binary_sentiSW_df.index)

sentiSW_plus = pd.concat([binary_sentiSW_df, sentiCR_df], ignore_index=True)
sentiSW_plus
